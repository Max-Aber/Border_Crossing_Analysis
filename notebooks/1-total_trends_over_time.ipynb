# %%
import sys
import pandas as pd
sys.path.append('..')

import scripts.plot_utils as plot

# Load data
df = pd.read_csv('../data/processed/measure_crossings.csv')

# %%
df_personal = df[df['Measure'] == 'Personal Transportation']
df_personal['Date'] = pd.to_datetime(df_personal['Date'])
df_personal = df_personal[df_personal["Date"] >= '2019-01-01']
plot.plot_time_series(df_personal, "Date", "Monthly_Crossings",'Total Personal Transportation Crossings Over Time', 'Date', 'Total Crossings')
# Out:
# C:\Users\maxim\AppData\Local\Temp\ipykernel_23768\3335684666.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_personal['Date'] = pd.to_datetime(df_personal['Date'])
